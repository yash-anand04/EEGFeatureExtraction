# %% [markdown]
# # LSTM Pure AI Baseline
# ## 1. Setup
# End-to-end LOSO benchmark using an LSTM regressor.

# %% [markdown]
# ## Notebook Flow
# 1. Configure paths and parameters.
# 2. Define reusable helper functions.
# 3. Train/evaluate the method on LOSO splits.
# 4. Save metrics (CSV/JSON) and plot artifacts (PNG) in this folder.

# %% [markdown]
# ## 2. Data, Utilities, and Method Definition
# This section defines constants, helper functions, and model architecture used by the benchmark.

# %%
# --- 1) Imports and core setup ---

# This section centralizes dependencies, path discovery, and run configuration.

# Keeping setup here makes the remaining cells method-focused and easier to debug.



from pathlib import Path

import json

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import torch

import torch.nn as nn

from torch.utils.data import DataLoader, TensorDataset



def find_repo_root(start: Path) -> Path:

    # Locate repository root by scanning parent directories.

    for candidate in [start, *start.parents]:

        if (candidate / 'processed').exists() and (candidate / 'Main_codes').exists():

            return candidate

    raise RuntimeError('Could not locate repository root.')

REPO_ROOT = find_repo_root(Path.cwd().resolve())

NOTEBOOK_DIR = REPO_ROOT / 'Main_codes' / 'Baseline_analysis' / 'Pure_AI_models' / 'lstm'

NOTEBOOK_DIR.mkdir(parents=True, exist_ok=True)

PROCESSED_DIR = REPO_ROOT / 'processed' / 'bci_competition_iv_2a'

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

CHANNELS_22 = ['Fz','FC3','FC1','FCz','FC2','FC4','C5','C3','C1','Cz','C2','C4','C6','CP3','CP1','CPz','CP2','CP4','P1','Pz','P2','POz']

CHANNEL_SET_5 = ['Fz', 'C3', 'C4', 'Pz', 'POz']

CHANNEL_SET_10 = ['Fz', 'FC3', 'FC4', 'C3', 'Cz', 'C4', 'CP3', 'CP4', 'Pz', 'POz']

CHANNEL_SET_15 = ['Fz', 'FC3', 'FC1', 'FC2', 'FC4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CP3', 'CP1', 'CP2', 'CP4', 'Pz']

def load_subject_data(subject_dir: Path):

    # Load one subject's preprocessed EEG trials and labels from NPZ.

    npz=np.load(subject_dir / 'trials.npz', allow_pickle=True)

    return npz['X'].astype(np.float32), npz['y'].astype(np.int32)

def to_sample_matrix(trials):

    # Reshape trial-wise EEG to sample-wise matrix for model training/evaluation.

    n_trials,n_channels,n_times=trials.shape

    return np.transpose(trials,(0,2,1)).reshape(n_trials*n_times,n_channels)

class LSTMRegressor(nn.Module):

    def __init__(self,n_input,n_output,hidden=64):

        super().__init__()

        self.lstm=nn.LSTM(input_size=1, hidden_size=hidden, num_layers=1, batch_first=True)

        self.head=nn.Sequential(nn.Linear(hidden,128), nn.ReLU(), nn.Linear(128,n_output))

    def forward(self,x):

        out,_=self.lstm(x.unsqueeze(-1))

        return self.head(out[:,-1,:])

def train_model(model, x_train, y_train, epochs=12, batch_size=512, lr=1e-3, val_frac=0.1):
    # Train with per-epoch train/validation loss logging to monitor over/underfitting.
    x_t = torch.tensor(x_train, dtype=torch.float32)
    y_t = torch.tensor(y_train, dtype=torch.float32)

    n_total = x_t.shape[0]
    n_val = max(1, int(n_total * val_frac))
    perm = torch.randperm(n_total)
    val_idx = perm[:n_val]
    train_idx = perm[n_val:]
    if train_idx.numel() == 0:
        train_idx = val_idx
        val_idx = perm[:1]

    train_ds = TensorDataset(x_t[train_idx], y_t[train_idx])
    val_ds = TensorDataset(x_t[val_idx], y_t[val_idx])

    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_dl = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    model.to(DEVICE)

    for epoch in range(1, epochs + 1):
        model.train()
        train_loss_sum = 0.0
        train_count = 0
        for xb, yb in train_dl:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            opt.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            opt.step()
            train_loss_sum += loss.item() * xb.shape[0]
            train_count += xb.shape[0]
        train_loss = train_loss_sum / max(train_count, 1)

        model.eval()
        val_loss_sum = 0.0
        val_count = 0
        with torch.no_grad():
            for xb, yb in val_dl:
                xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                pred = model(xb)
                loss = loss_fn(pred, yb)
                val_loss_sum += loss.item() * xb.shape[0]
                val_count += xb.shape[0]
        val_loss = val_loss_sum / max(val_count, 1)

        print(f"Epoch {epoch:02d}/{epochs} | train_loss={train_loss:.6f} | val_loss={val_loss:.6f}")

    return model

def predict_model(model,x):

    # Run model inference on test samples and return numpy predictions.

    model.eval()

    with torch.no_grad(): return model(torch.tensor(x,dtype=torch.float32,device=DEVICE)).cpu().numpy()

def compute_metrics(y_true,y_pred):

    # Compute reconstruction fidelity metrics (RMSE, MAE, Pearson r, R2).

    diff=y_true-y_pred; rmse=float(np.sqrt(np.mean(diff**2))); mae=float(np.mean(np.abs(diff)))

    yt=y_true.reshape(-1); yp=y_pred.reshape(-1); yt_c=yt-yt.mean(); yp_c=yp-yp.mean()

    den=np.sqrt(np.sum(yt_c**2)*np.sum(yp_c**2)); pearson_r=float(np.sum(yt_c*yp_c)/den) if den>0 else np.nan

    ss_res=float(np.sum((yt-yp)**2)); ss_tot=float(np.sum((yt-yt.mean())**2)); r2=float(1-ss_res/ss_tot) if ss_tot>0 else np.nan

    return {'rmse': rmse, 'mae': mae, 'pearson_r': pearson_r, 'r2': r2}

MAX_SPLITS=0; MAX_TRAIN_SAMPLES=60000; MAX_TEST_SAMPLES=20000; RNG=np.random.default_rng(42)

loso_splits=json.loads((PROCESSED_DIR / 'loso_splits.json').read_text(encoding='utf-8'))

if MAX_SPLITS>0: loso_splits=loso_splits[:MAX_SPLITS]

# %% [markdown]
# ## 3. LOSO Training and Evaluation
# This section runs subject-wise train/test evaluation and computes reconstruction metrics.

# %%
rows=[]
for split in loso_splits:
    test_subject=split['test_subject']; train_subjects=split['train_subjects']
    train_samples=np.concatenate([to_sample_matrix(load_subject_data(PROCESSED_DIR / s)[0]) for s in train_subjects],axis=0)
    if MAX_TRAIN_SAMPLES>0 and train_samples.shape[0]>MAX_TRAIN_SAMPLES:
        train_samples=train_samples[RNG.choice(train_samples.shape[0],size=MAX_TRAIN_SAMPLES,replace=False)]
    test_samples=to_sample_matrix(load_subject_data(PROCESSED_DIR / test_subject)[0])
    if MAX_TEST_SAMPLES>0 and test_samples.shape[0]>MAX_TEST_SAMPLES:
        test_samples=test_samples[RNG.choice(test_samples.shape[0],size=MAX_TEST_SAMPLES,replace=False)]
    for input_channels in [CHANNEL_SET_5, CHANNEL_SET_10, CHANNEL_SET_15]:
        input_idx=[CHANNELS_22.index(c) for c in input_channels]; missing_channels=[c for c in CHANNELS_22 if c not in input_channels]; missing_idx=[CHANNELS_22.index(c) for c in missing_channels]
        x_train,y_train=train_samples[:,input_idx],train_samples[:,missing_idx]; x_test,y_test=test_samples[:,input_idx],test_samples[:,missing_idx]
        model=train_model(LSTMRegressor(x_train.shape[1], y_train.shape[1]), x_train, y_train)
        pred=predict_model(model,x_test); metrics=compute_metrics(y_test,pred)
        rows.append({'test_subject': test_subject,'n_input_channels': len(input_channels),'input_channels': ','.join(input_channels),'n_reconstructed_channels': len(missing_channels),'method': 'lstm', **metrics,'n_test_samples': int(x_test.shape[0])})
df=pd.DataFrame(rows); df.head()
# Out:
# Epoch 01/12 | train_loss=62.568976 | val_loss=23.840501
# Epoch 02/12 | train_loss=19.585952 | val_loss=14.812379
# Epoch 03/12 | train_loss=13.870944 | val_loss=12.904446
# Epoch 04/12 | train_loss=13.009736 | val_loss=12.406987
# Epoch 05/12 | train_loss=12.665535 | val_loss=12.208527
# Epoch 06/12 | train_loss=12.459169 | val_loss=12.092334
# Epoch 07/12 | train_loss=12.215967 | val_loss=11.799003
# Epoch 08/12 | train_loss=11.698505 | val_loss=10.950013
# Epoch 09/12 | train_loss=9.855025 | val_loss=8.316167
# Epoch 10/12 | train_loss=7.947853 | val_loss=7.488938
# Epoch 11/12 | train_loss=7.442828 | val_loss=7.163464
# Epoch 12/12 | train_loss=7.144846 | val_loss=6.985108
# Epoch 01/12 | train_loss=60.298847 | val_loss=23.091058
# Epoch 02/12 | train_loss=16.522035 | val_loss=13.845157
# Epoch 03/12 | train_loss=11.851944 | val_loss=12.411120
# Epoch 04/12 | train_loss=11.206943 | val_loss=11.874590
# Epoch 05/12 | train_loss=10.945141 | val_loss=11.512235
# Epoch 06/12 | train_loss=10.792897 | val_loss=11.209867
# Epoch 07/12 | train_loss=10.616677 | val_loss=10.985598
# Epoch 08/12 | train_loss=10.420631 | val_loss=10.728205
# Epoch 09/12 | train_loss=10.202460 | val_loss=10.397435
# Epoch 10/12 | train_loss=9.852068 | val_loss=10.009087
# Epoch 11/12 | train_loss=9.196795 | val_loss=8.816024
# Epoch 12/12 | train_loss=7.576372 | val_loss=7.432989
# Epoch 01/12 | train_loss=62.550312 | val_loss=26.887375
# Epoch 02/12 | train_loss=20.453718 | val_loss=14.765128
# Epoch 03/12 | train_loss=13.870802 | val_loss=12.824190
# Epoch 04/12 | train_loss=11.787658 | val_loss=9.931514
# Epoch 05/12 | train_loss=9.675971 | val_loss=9.278302
# Epoch 06/12 | train_loss=9.268087 | val_loss=8.968328
# Epoch 07/12 | train_loss=8.937200 | val_loss=8.655504
# Epoch 08/12 | train_loss=8.424914 | val_loss=8.173617
# Epoch 09/12 | train_loss=7.641699 | val_loss=7.247092
# Epoch 10/12 | train_loss=7.061759 | val_loss=6.936050
# Epoch 11/12 | train_loss=6.790877 | val_loss=6.710440
# Epoch 12/12 | train_loss=6.613549 | val_loss=6.616916
# Epoch 01/12 | train_loss=63.798279 | val_loss=24.685551
# Epoch 02/12 | train_loss=20.755834 | val_loss=17.311434
# Epoch 03/12 | train_loss=14.802511 | val_loss=13.711225
# Epoch 04/12 | train_loss=13.275693 | val_loss=13.003794
# Epoch 05/12 | train_loss=12.787876 | val_loss=12.556084
# Epoch 06/12 | train_loss=12.379809 | val_loss=12.103816
# Epoch 07/12 | train_loss=11.864774 | val_loss=11.501625
# Epoch 08/12 | train_loss=11.192746 | val_loss=10.697766
# Epoch 09/12 | train_loss=10.194059 | val_loss=9.333268
# Epoch 10/12 | train_loss=8.594305 | val_loss=8.058829
# Epoch 11/12 | train_loss=7.863522 | val_loss=7.676447
# Epoch 12/12 | train_loss=7.598534 | val_loss=7.593442
# Epoch 01/12 | train_loss=61.127383 | val_loss=20.399372
# Epoch 02/12 | train_loss=16.636426 | val_loss=12.271835
# Epoch 03/12 | train_loss=12.108025 | val_loss=11.223950
# Epoch 04/12 | train_loss=11.507689 | val_loss=10.928837
# Epoch 05/12 | train_loss=11.256305 | val_loss=10.779093
# Epoch 06/12 | train_loss=11.103854 | val_loss=10.641394
# Epoch 07/12 | train_loss=10.957027 | val_loss=10.559268
# Epoch 08/12 | train_loss=10.802827 | val_loss=10.378087
# Epoch 09/12 | train_loss=10.606150 | val_loss=10.192702
# Epoch 10/12 | train_loss=10.405598 | val_loss=10.023394
# Epoch 11/12 | train_loss=10.184712 | val_loss=9.743545
# Epoch 12/12 | train_loss=9.947068 | val_loss=9.747377
# Epoch 01/12 | train_loss=60.855817 | val_loss=27.201419
# Epoch 02/12 | train_loss=21.012029 | val_loss=14.517200
# Epoch 03/12 | train_loss=14.065060 | val_loss=13.138521
# Epoch 04/12 | train_loss=12.011679 | val_loss=10.063371
# Epoch 05/12 | train_loss=9.863631 | val_loss=9.349838
# Epoch 06/12 | train_loss=9.426638 | val_loss=9.104243
# Epoch 07/12 | train_loss=9.168052 | val_loss=8.884668
# Epoch 08/12 | train_loss=8.934752 | val_loss=8.588789
# Epoch 09/12 | train_loss=8.610956 | val_loss=8.128526
# Epoch 10/12 | train_loss=7.962196 | val_loss=7.458340
# Epoch 11/12 | train_loss=7.401637 | val_loss=7.019713
# Epoch 12/12 | train_loss=7.034633 | val_loss=6.787188
# Epoch 01/12 | train_loss=60.597221 | val_loss=24.405972
# Epoch 02/12 | train_loss=19.438157 | val_loss=15.694834
# Epoch 03/12 | train_loss=14.169770 | val_loss=13.504675
# Epoch 04/12 | train_loss=13.036727 | val_loss=12.803564
# Epoch 05/12 | train_loss=12.563086 | val_loss=12.402649
# Epoch 06/12 | train_loss=12.183318 | val_loss=12.010058
# Epoch 07/12 | train_loss=11.670376 | val_loss=11.357460
# Epoch 08/12 | train_loss=10.844618 | val_loss=10.307824
# Epoch 09/12 | train_loss=9.278047 | val_loss=8.304146
# Epoch 10/12 | train_loss=7.868319 | val_loss=7.608647
# Epoch 11/12 | train_loss=7.437442 | val_loss=7.323985
# Epoch 12/12 | train_loss=7.176102 | val_loss=7.102815
# Epoch 01/12 | train_loss=57.991893 | val_loss=21.162090
# Epoch 02/12 | train_loss=18.300679 | val_loss=13.627642
# Epoch 03/12 | train_loss=12.216224 | val_loss=11.253257
# Epoch 04/12 | train_loss=11.229073 | val_loss=10.689202
# Epoch 05/12 | train_loss=10.819690 | val_loss=10.464688
# Epoch 06/12 | train_loss=10.531741 | val_loss=10.147743
# Epoch 07/12 | train_loss=10.216204 | val_loss=9.854202
# Epoch 08/12 | train_loss=9.957485 | val_loss=9.537619
# Epoch 09/12 | train_loss=9.575740 | val_loss=9.084039
# Epoch 10/12 | train_loss=8.966525 | val_loss=8.164435
# Epoch 11/12 | train_loss=7.722520 | val_loss=6.948523
# Epoch 12/12 | train_loss=6.832617 | val_loss=6.428715
# Epoch 01/12 | train_loss=57.995052 | val_loss=27.108502
# Epoch 02/12 | train_loss=19.579236 | val_loss=14.919901
# Epoch 03/12 | train_loss=13.522103 | val_loss=13.372014
# Epoch 04/12 | train_loss=11.878761 | val_loss=10.256540
# Epoch 05/12 | train_loss=9.350387 | val_loss=9.116732
# Epoch 06/12 | train_loss=8.801488 | val_loss=8.712101
# Epoch 07/12 | train_loss=8.365206 | val_loss=8.190454
# Epoch 08/12 | train_loss=7.666551 | val_loss=7.342087
# Epoch 09/12 | train_loss=6.993460 | val_loss=6.994741
# Epoch 10/12 | train_loss=6.656824 | val_loss=6.613994
# Epoch 11/12 | train_loss=6.428146 | val_loss=6.373590
# Epoch 12/12 | train_loss=6.226947 | val_loss=6.319817
# Epoch 01/12 | train_loss=66.533665 | val_loss=23.532909
# Epoch 02/12 | train_loss=19.673441 | val_loss=15.556749
# Epoch 03/12 | train_loss=14.397470 | val_loss=13.295084
# Epoch 04/12 | train_loss=13.271392 | val_loss=12.792473
# Epoch 05/12 | train_loss=12.869930 | val_loss=12.625191
# Epoch 06/12 | train_loss=12.510773 | val_loss=12.139702
# Epoch 07/12 | train_loss=12.102024 | val_loss=11.666396
# Epoch 08/12 | train_loss=11.475487 | val_loss=10.938152
# Epoch 09/12 | train_loss=10.501581 | val_loss=9.637051
# Epoch 10/12 | train_loss=8.808776 | val_loss=8.051283
# Epoch 11/12 | train_loss=7.815747 | val_loss=7.480930
# Epoch 12/12 | train_loss=7.375182 | val_loss=7.147400
# Epoch 01/12 | train_loss=60.786280 | val_loss=21.346706
# Epoch 02/12 | train_loss=17.331986 | val_loss=12.890927
# Epoch 03/12 | train_loss=12.204144 | val_loss=11.606458
# Epoch 04/12 | train_loss=11.431113 | val_loss=11.172172
# Epoch 05/12 | train_loss=11.112871 | val_loss=11.009283
# Epoch 06/12 | train_loss=10.868626 | val_loss=10.719692
# Epoch 07/12 | train_loss=10.675629 | val_loss=10.547671
# Epoch 08/12 | train_loss=10.435973 | val_loss=10.480117
# Epoch 09/12 | train_loss=10.196276 | val_loss=10.026800
# Epoch 10/12 | train_loss=9.871335 | val_loss=9.650691
# Epoch 11/12 | train_loss=9.174372 | val_loss=8.457631
# Epoch 12/12 | train_loss=7.846515 | val_loss=7.343000
# Epoch 01/12 | train_loss=61.114843 | val_loss=25.970982
# Epoch 02/12 | train_loss=20.773597 | val_loss=14.982433
# Epoch 03/12 | train_loss=14.109605 | val_loss=13.098122
# Epoch 04/12 | train_loss=11.844797 | val_loss=10.044287
# Epoch 05/12 | train_loss=9.742857 | val_loss=9.282753
# Epoch 06/12 | train_loss=9.279751 | val_loss=8.988058
# Epoch 07/12 | train_loss=8.943902 | val_loss=8.628588
# Epoch 08/12 | train_loss=8.568323 | val_loss=8.251038
# Epoch 09/12 | train_loss=8.099634 | val_loss=7.664756
# Epoch 10/12 | train_loss=7.414478 | val_loss=7.210818
# Epoch 11/12 | train_loss=7.031884 | val_loss=6.896077
# Epoch 12/12 | train_loss=6.809140 | val_loss=6.733997
# Epoch 01/12 | train_loss=65.818780 | val_loss=24.469885
# Epoch 02/12 | train_loss=19.595396 | val_loss=15.210474
# Epoch 03/12 | train_loss=14.414972 | val_loss=13.787193
# Epoch 04/12 | train_loss=13.518230 | val_loss=13.197931
# Epoch 05/12 | train_loss=13.211242 | val_loss=13.128727
# Epoch 06/12 | train_loss=12.966599 | val_loss=12.758750
# Epoch 07/12 | train_loss=12.680200 | val_loss=12.409466
# Epoch 08/12 | train_loss=12.210706 | val_loss=11.740844
# Epoch 09/12 | train_loss=11.155050 | val_loss=9.935774
# Epoch 10/12 | train_loss=8.913171 | val_loss=8.164715
# Epoch 11/12 | train_loss=7.994466 | val_loss=7.722986
# Epoch 12/12 | train_loss=7.656823 | val_loss=7.532093
# Epoch 01/12 | train_loss=60.975341 | val_loss=22.101965
# Epoch 02/12 | train_loss=17.961756 | val_loss=13.761774
# Epoch 03/12 | train_loss=12.567572 | val_loss=12.132836
# Epoch 04/12 | train_loss=11.855312 | val_loss=11.747552
# Epoch 05/12 | train_loss=11.589894 | val_loss=11.512842
# Epoch 06/12 | train_loss=11.412234 | val_loss=11.575407
# Epoch 07/12 | train_loss=11.256972 | val_loss=11.243969
# Epoch 08/12 | train_loss=11.042394 | val_loss=11.030753
# Epoch 09/12 | train_loss=10.847679 | val_loss=10.772205
# Epoch 10/12 | train_loss=10.569702 | val_loss=10.482594
# Epoch 11/12 | train_loss=10.227712 | val_loss=10.004372
# Epoch 12/12 | train_loss=9.381193 | val_loss=8.631676
# Epoch 01/12 | train_loss=61.010394 | val_loss=28.229594
# Epoch 02/12 | train_loss=20.909657 | val_loss=16.121401
# Epoch 03/12 | train_loss=14.450592 | val_loss=14.567388
# Epoch 04/12 | train_loss=13.237641 | val_loss=12.441855
# Epoch 05/12 | train_loss=10.520391 | val_loss=10.353745
# Epoch 06/12 | train_loss=9.696971 | val_loss=9.977959
# Epoch 07/12 | train_loss=9.370280 | val_loss=9.596116
# Epoch 08/12 | train_loss=9.074732 | val_loss=9.230552
# Epoch 09/12 | train_loss=8.670779 | val_loss=8.710808
# Epoch 10/12 | train_loss=7.986489 | val_loss=7.966022
# Epoch 11/12 | train_loss=7.417902 | val_loss=7.581010
# Epoch 12/12 | train_loss=7.179161 | val_loss=7.387768
# Epoch 01/12 | train_loss=58.814778 | val_loss=21.393256
# Epoch 02/12 | train_loss=18.306038 | val_loss=13.807937
# Epoch 03/12 | train_loss=12.935651 | val_loss=11.864939
# Epoch 04/12 | train_loss=11.978439 | val_loss=11.422454
# Epoch 05/12 | train_loss=11.677566 | val_loss=11.250074
# Epoch 06/12 | train_loss=11.477078 | val_loss=11.086135
# Epoch 07/12 | train_loss=11.149197 | val_loss=10.680933
# Epoch 08/12 | train_loss=10.597272 | val_loss=9.903906
# Epoch 09/12 | train_loss=9.319746 | val_loss=8.179559
# Epoch 10/12 | train_loss=7.668271 | val_loss=7.063370
# Epoch 11/12 | train_loss=7.075458 | val_loss=6.766820
# Epoch 12/12 | train_loss=6.848100 | val_loss=6.622673
# Epoch 01/12 | train_loss=56.620221 | val_loss=20.262324
# Epoch 02/12 | train_loss=16.170081 | val_loss=12.745034
# Epoch 03/12 | train_loss=11.381984 | val_loss=10.827526
# Epoch 04/12 | train_loss=10.465896 | val_loss=10.399341
# Epoch 05/12 | train_loss=10.171968 | val_loss=10.107482
# Epoch 06/12 | train_loss=10.010127 | val_loss=10.009773
# Epoch 07/12 | train_loss=9.859668 | val_loss=9.804402
# Epoch 08/12 | train_loss=9.701281 | val_loss=9.633801
# Epoch 09/12 | train_loss=9.505174 | val_loss=9.403829
# Epoch 10/12 | train_loss=9.261796 | val_loss=9.132746
# Epoch 11/12 | train_loss=8.898533 | val_loss=8.582568
# Epoch 12/12 | train_loss=7.758192 | val_loss=7.100571
# Epoch 01/12 | train_loss=57.509517 | val_loss=24.555389
# Epoch 02/12 | train_loss=18.884524 | val_loss=13.884232
# Epoch 03/12 | train_loss=13.000333 | val_loss=12.655820
# Epoch 04/12 | train_loss=11.659677 | val_loss=10.426319
# Epoch 05/12 | train_loss=9.273154 | val_loss=8.931900
# Epoch 06/12 | train_loss=8.624778 | val_loss=8.607358
# Epoch 07/12 | train_loss=8.360604 | val_loss=8.344451
# Epoch 08/12 | train_loss=8.109952 | val_loss=8.140395
# Epoch 09/12 | train_loss=7.858106 | val_loss=7.739973
# Epoch 10/12 | train_loss=7.413340 | val_loss=7.329602
# Epoch 11/12 | train_loss=6.925000 | val_loss=6.849200
# Epoch 12/12 | train_loss=6.589599 | val_loss=6.582719
# Epoch 01/12 | train_loss=63.609215 | val_loss=24.177032
# Epoch 02/12 | train_loss=19.660996 | val_loss=15.934123
# Epoch 03/12 | train_loss=14.093272 | val_loss=13.744312
# Epoch 04/12 | train_loss=13.118515 | val_loss=13.210011
# Epoch 05/12 | train_loss=12.782455 | val_loss=13.064257
# Epoch 06/12 | train_loss=12.607986 | val_loss=12.799920
# Epoch 07/12 | train_loss=12.368075 | val_loss=12.534952
# Epoch 08/12 | train_loss=12.026377 | val_loss=11.949019
# Epoch 09/12 | train_loss=11.349629 | val_loss=10.921539
# Epoch 10/12 | train_loss=9.619331 | val_loss=8.470276
# Epoch 11/12 | train_loss=7.978363 | val_loss=7.780509
# Epoch 12/12 | train_loss=7.559657 | val_loss=7.485659
# Epoch 01/12 | train_loss=63.028630 | val_loss=20.522947
# Epoch 02/12 | train_loss=17.493034 | val_loss=12.762724
# Epoch 03/12 | train_loss=12.232275 | val_loss=11.451670
# Epoch 04/12 | train_loss=11.469771 | val_loss=11.067284
# Epoch 05/12 | train_loss=11.150678 | val_loss=10.776381
# Epoch 06/12 | train_loss=10.871730 | val_loss=10.495269
# Epoch 07/12 | train_loss=10.548956 | val_loss=10.182506
# Epoch 08/12 | train_loss=10.201267 | val_loss=9.772933
# Epoch 09/12 | train_loss=9.418120 | val_loss=8.457979
# Epoch 10/12 | train_loss=8.013260 | val_loss=7.463042
# Epoch 11/12 | train_loss=7.258794 | val_loss=6.863650
# Epoch 12/12 | train_loss=6.806450 | val_loss=6.546647
# Epoch 01/12 | train_loss=61.820632 | val_loss=27.381718
# Epoch 02/12 | train_loss=21.052051 | val_loss=14.735448
# Epoch 03/12 | train_loss=13.968704 | val_loss=12.795155
# Epoch 04/12 | train_loss=11.289115 | val_loss=9.820873
# Epoch 05/12 | train_loss=9.632529 | val_loss=9.300958
# Epoch 06/12 | train_loss=9.275706 | val_loss=9.123476
# Epoch 07/12 | train_loss=9.064690 | val_loss=8.892686
# Epoch 08/12 | train_loss=8.823399 | val_loss=8.597969
# Epoch 09/12 | train_loss=8.408674 | val_loss=8.014712
# Epoch 10/12 | train_loss=7.811839 | val_loss=7.441670
# Epoch 11/12 | train_loss=7.458433 | val_loss=7.241707
# Epoch 12/12 | train_loss=7.236341 | val_loss=7.102389
# Epoch 01/12 | train_loss=56.323498 | val_loss=21.823479
# Epoch 02/12 | train_loss=17.324941 | val_loss=13.795581
# Epoch 03/12 | train_loss=12.839544 | val_loss=12.283301
# Epoch 04/12 | train_loss=12.098258 | val_loss=11.812647
# Epoch 05/12 | train_loss=11.810579 | val_loss=11.591234
# Epoch 06/12 | train_loss=11.638978 | val_loss=11.422098
# Epoch 07/12 | train_loss=11.453195 | val_loss=11.204452
# Epoch 08/12 | train_loss=11.170870 | val_loss=10.863786
# Epoch 09/12 | train_loss=10.551234 | val_loss=9.971661
# Epoch 10/12 | train_loss=8.867694 | val_loss=7.908660
# Epoch 11/12 | train_loss=7.498301 | val_loss=7.236802
# Epoch 12/12 | train_loss=7.092301 | val_loss=6.953122
# Epoch 01/12 | train_loss=54.220117 | val_loss=20.018491
# Epoch 02/12 | train_loss=15.296247 | val_loss=11.911148
# Epoch 03/12 | train_loss=11.138978 | val_loss=10.931865
# Epoch 04/12 | train_loss=10.573209 | val_loss=10.598119
# Epoch 05/12 | train_loss=10.334994 | val_loss=10.288931
# Epoch 06/12 | train_loss=10.050174 | val_loss=9.991658
# Epoch 07/12 | train_loss=9.775030 | val_loss=9.704104
# Epoch 08/12 | train_loss=9.484950 | val_loss=9.490232
# Epoch 09/12 | train_loss=8.991020 | val_loss=8.395796
# Epoch 10/12 | train_loss=7.678151 | val_loss=7.228732
# Epoch 11/12 | train_loss=6.856104 | val_loss=6.668168
# Epoch 12/12 | train_loss=6.498096 | val_loss=6.482142
# Epoch 01/12 | train_loss=55.738665 | val_loss=23.850729
# Epoch 02/12 | train_loss=18.248933 | val_loss=13.393600
# Epoch 03/12 | train_loss=12.762570 | val_loss=12.254139
# Epoch 04/12 | train_loss=11.130815 | val_loss=9.621008
# Epoch 05/12 | train_loss=9.142049 | val_loss=8.900414
# Epoch 06/12 | train_loss=8.705326 | val_loss=8.554206
# Epoch 07/12 | train_loss=8.361358 | val_loss=8.188713
# Epoch 08/12 | train_loss=7.946109 | val_loss=7.803906
# Epoch 09/12 | train_loss=7.342685 | val_loss=7.033385
# Epoch 10/12 | train_loss=6.785584 | val_loss=6.597684
# Epoch 11/12 | train_loss=6.484014 | val_loss=6.447250
# Epoch 12/12 | train_loss=6.278865 | val_loss=6.244563
# Epoch 01/12 | train_loss=54.722385 | val_loss=19.219683
# Epoch 02/12 | train_loss=16.582481 | val_loss=13.778003
# Epoch 03/12 | train_loss=11.869474 | val_loss=11.045888
# Epoch 04/12 | train_loss=10.855829 | val_loss=10.692170
# Epoch 05/12 | train_loss=10.578172 | val_loss=10.443284
# Epoch 06/12 | train_loss=10.433368 | val_loss=10.344185
# Epoch 07/12 | train_loss=10.315551 | val_loss=10.285662
# Epoch 08/12 | train_loss=10.163652 | val_loss=10.093831
# Epoch 09/12 | train_loss=9.891801 | val_loss=9.688099
# Epoch 10/12 | train_loss=9.391115 | val_loss=8.934225
# Epoch 11/12 | train_loss=8.141832 | val_loss=7.226198
# Epoch 12/12 | train_loss=6.794109 | val_loss=6.503490
# Epoch 01/12 | train_loss=52.340658 | val_loss=18.541334
# Epoch 02/12 | train_loss=15.560309 | val_loss=13.093437
# Epoch 03/12 | train_loss=10.701921 | val_loss=10.262713
# Epoch 04/12 | train_loss=9.708464 | val_loss=9.834117
# Epoch 05/12 | train_loss=9.448393 | val_loss=9.695631
# Epoch 06/12 | train_loss=9.320480 | val_loss=9.507008
# Epoch 07/12 | train_loss=9.200075 | val_loss=9.592604
# Epoch 08/12 | train_loss=9.074967 | val_loss=9.242250
# Epoch 09/12 | train_loss=8.905040 | val_loss=9.062595
# Epoch 10/12 | train_loss=8.738299 | val_loss=8.929249
# Epoch 11/12 | train_loss=8.563937 | val_loss=8.714345
# Epoch 12/12 | train_loss=8.320432 | val_loss=8.383230
# Epoch 01/12 | train_loss=51.094050 | val_loss=22.282222
# Epoch 02/12 | train_loss=17.310988 | val_loss=12.689480
# Epoch 03/12 | train_loss=11.663609 | val_loss=11.583801
# Epoch 04/12 | train_loss=11.141049 | val_loss=11.037753
# Epoch 05/12 | train_loss=9.448053 | val_loss=8.728304
# Epoch 06/12 | train_loss=8.094519 | val_loss=8.132016
# Epoch 07/12 | train_loss=7.733401 | val_loss=7.837236
# Epoch 08/12 | train_loss=7.356085 | val_loss=7.346866
# Epoch 09/12 | train_loss=6.843907 | val_loss=6.878518
# Epoch 10/12 | train_loss=6.428160 | val_loss=6.414372
# Epoch 11/12 | train_loss=6.179563 | val_loss=6.212062
# Epoch 12/12 | train_loss=5.956213 | val_loss=6.058455
#   test_subject  n_input_channels  \
# 0         A01T                 5
# 1         A01T                10
# 2         A01T                15
# 3         A02T                 5
# 4         A02T                10
#
#                                       input_channels  \
# 0                                    Fz,C3,C4,Pz,POz
# 1                 Fz,FC3,FC4,C3,Cz,C4,CP3,CP4,Pz,POz
# 2  Fz,FC3,FC1,FC2,FC4,C3,C1,Cz,C2,C4,CP3,CP1,CP2,...
# 3                                    Fz,C3,C4,Pz,POz
# 4                 Fz,FC3,FC4,C3,Cz,C4,CP3,CP4,Pz,POz
#
#    n_reconstructed_channels method      rmse       mae  pearson_r        r2  \
# 0                        17   lstm  2.334959  1.800938   0.972843  0.946237
# 1                        12   lstm  2.381454  1.805802   0.971875  0.943746
# 2                         7   lstm  2.276106  1.728133   0.972021  0.944619
# 3                        17   lstm  2.232244  1.665924   0.967794  0.935964
# 4                        12   lstm  2.602155  1.854565   0.956991  0.913291
#
#    n_test_samples
# 0           20000
# 1           20000
# 2           20000
# 3           20000
# 4           20000

# %% [markdown]
# ## 4. Export Metrics and Visualizations
# This section writes CSV/JSON summaries and saves plot artifacts to the method folder.

# %%
output_csv=NOTEBOOK_DIR / 'lstm_metrics.csv'; output_json=NOTEBOOK_DIR / 'lstm_summary.json'; plot_path=NOTEBOOK_DIR / 'lstm_metrics_plot.png'
df.to_csv(output_csv,index=False)
summary=df.groupby('n_input_channels',as_index=False)[['rmse','mae','pearson_r','r2']].mean()
output_json.write_text(json.dumps({'rows': int(len(df)), 'splits': int(len(loso_splits)), 'method': 'lstm', 'device': DEVICE, 'mean_metrics': summary.to_dict(orient='records')}, indent=2), encoding='utf-8')
fig, ax1 = plt.subplots(figsize=(8, 4))
ax1.plot(summary['n_input_channels'], summary['rmse'], marker='o', label='RMSE')
ax1.set_xlabel('Input channels')
ax1.set_ylabel('RMSE')
ax1.grid(True, alpha=0.3)
ax2 = ax1.twinx()
ax2.plot(summary['n_input_channels'], summary['pearson_r'], marker='s', color='tab:green', label='Pearson r')
ax2.plot(summary['n_input_channels'], summary['r2'], marker='^', color='tab:red', label='R2')
ax2.set_ylabel('Correlation / R2')
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='best')
fig.tight_layout()
fig.savefig(plot_path, dpi=150)
plt.show()
print('Saved:', output_csv)
print('Saved:', output_json)
print('Saved:', plot_path)
# Out:
# Saved: E:\Github\EEGFeatureExtraction\Main_codes\Baseline_analysis\Pure_AI_models\lstm\lstm_metrics.csv
# Saved: E:\Github\EEGFeatureExtraction\Main_codes\Baseline_analysis\Pure_AI_models\lstm\lstm_summary.json
# Saved: E:\Github\EEGFeatureExtraction\Main_codes\Baseline_analysis\Pure_AI_models\lstm\lstm_metrics_plot.png
