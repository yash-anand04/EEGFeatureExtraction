# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
# first get into each trial folder
trial_number = 8
print(os.listdir("."))
# format for trial folder is two digit number with leading zero if necessary
audio_and_visual_stimulus = os.path.join("Subject_1/Baseline (with_audio_and_visual_stimulus)",f"trial_{trial_number:02d}")
in_silence = os.path.join("Subject_1/Baseline (in_silence)",f"trial_{trial_number:02d}")
with_music = os.path.join("Subject_1/Baseline (with_music)",f"trial_{trial_number:02d}")
